# %% [markdown]
# ### ProtonX Leetcode 200 - Day 6 - In Class Exercies
# Cách lập trình:
# - Nếu là bài tập trên Leetcode
#     - Bạn lập trình thành công trên Leetcode
#     - Sau đó bạn sao chép thân hàm vào trong những phần có ghi chú **Lập trình tại đây**
#     - Sau đó bạn nộp lại bài tập qua hệ thống ProtonX để tính điểm
#
# - Chú ý: **Không sử dụng self** là đầu vào của hàm.
#
# Một câu: 60 điểm

# %% [markdown]
# ## Leetcode 20. Valid Parentheses
#
#
# Kiểm tra chuỗi đúng hay sai
#
# [Link bài tập](https://leetcode.com/problems/valid-parentheses/)

# %%
from typing import List

# %% [markdown]
# **Example 1:**
# ```
# Input: s = "()"
# Output: true
# ```
# **Example 2:**
# ```
# Input: s = "()[]{}"
# Output: true
# ```
# **Example 3:**
# ```
# Input: s = "(]"
# Output: false
# ```
#
# **Constraints:**
# ```
# 1 <= s.length <= 10**4
# s consists of parentheses only '()[]{}'
# ```

# %%
def isValid(s: str) -> bool:
    # Lập trình tại đây
    mapping = {")": "(", "}": "{", "]": "["}
    stack = []
    for char in s:
        if char not in mapping:
            stack.append(char)
        else:
            top_element = stack.pop() if stack else '#'
            if mapping[char] != top_element:
                return False
    if stack:
        return False
    return True

# %% [markdown]
# ## Leetcode 1047. Remove All Adjacent Duplicates In String
#
#
# Dạng đề bài yêu cầu xóa 2 ký tự giống nhau liền kề trong chuỗi
#
# [Link bài tập](https://leetcode.com/problems/remove-all-adjacent-duplicates-in-string/)

# %% [markdown]
# **Example 1:**
# ```
# Input: s = "abbaca"
# Output: "ca"
# Explanation:
# For example, in "abbaca" we could remove "bb" since the letters are adjacent and equal, and this is the only possible move.  The result of this move is that the string is "aaca", of which only "aa" is possible, so the final string is "ca".
# ```
# **Example 2:**
# ```
# Input: s = "azxxzy"
# Output: "ay"
# ```
# **Constraints:**
# ```
# 1 <= s.length <= 10**5
# s consists of lowercase English letters.
# ```

# %%
def removeDuplicates(s: str) -> str:
    # Lập trình tại đây
    result = []
    for char in s:
        if result and char == result[-1]:
            result.pop()
        else:
            result.append(char)
    return ''.join(result)
